# %%
import pandas as pd

# %%
df = pd.read_csv('phones_02.csv', encoding='latin1')
df
# Out:
#                                    product_name  \
# 0                                    OnePlus 6T
# 1                       Samsung Galaxy S20 Plus
# 2                               Apple iPhone XR
# 3                               Apple iPhone 11
# 4                       Apple iPhone 11 Pro Max
# 5                                 OnePlus 8 Pro
# 6                             Google Pixel 4 XL
# 7                                 OnePLus 7 Pro
# 8                       Xiaomi Redmi Note 9 Pro
# 9                           Xiaomi Redmi Note 9
# 10  Samsung Electronics Galaxy Note 20 Ultra 5G
# 11                       Samsung Galaxy A71 5G
# 12                           Samsung Galaxy A51
# 13     Samsung Galaxy A51 Storage Compatibility
# 14                     Samsung Galaxy S20 FE 5G
# 15                          OnePlus Nord N10 5G
# 16                                 Moto G Power
# 17                          Motorola One 5G Ace
# 18                                Moto G Stylus
# 19                                 Moto G Play
# 20                                   Sony H3123
# 21                                Motorola Edge
# 22                          Motorola One Action
# 23                                Moto G Stylus
# 24                           Moto G Stylus 2020
# 25                                 Moto G Power
# 26                                 Moto G Fast
# 27                                       Moto E
#
#                                           product_url  \
# 0   https://www.amazon.in/OnePlus-Mirror-Black-128...
# 1   https://www.amazon.com/Samsung-Unlocked-Finger...
# 2   https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 3   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 4   https://www.amazon.com/Apple-iPhone-Midnight-U...
# 5   https://www.amazon.com/OnePlus-Unlocked-IN2025...
# 6   https://www.amazon.com/Google-Pixel-XL-Black-U...
# 7   https://www.amazon.com/Oneplus-GM1910-Unlocked...
# 8   https://www.amazon.com/Xiaomi-Redmi-Note-Pro-D...
# 9   https://www.amazon.com/Xiaomi-Redmi-Note-Pro-D...
# 10  https://www.amazon.com/Samsung-Electronics-Unl...
# 11  https://www.amazon.com/Samsung-Unlocked-Storag...
# 12  https://www.amazon.com/Samsung-Galaxy-SM-A515F...
# 13  amazon.com/Samsung-Factory-Unlocked-Storage-Co...
# 14  https://www.amazon.com/Samsung-Factory-Unlocke...
# 15  https://www.amazon.com/OnePlus-Unlocked-Smartp...
# 16  https://www.amazon.com/Power-Battery-Unlocked-...
# 17  https://www.amazon.com/dp/B08NWD7K8H/ref=emc_b...
# 18  https://www.amazon.com/dp/B08NWF8SL4/ref=emc_b...
# 19  https://www.amazon.com/dp/B08NWGBHG3/ref=emc_b...
# 20  https://www.amazon.com/Sony-H3123-SBH-90C-Acce...
# 21  https://www.amazon.com/Motorola-Unlocked-256GB...
# 22  https://www.amazon.com/dp/B07WJJFKYW/ref=emc_b...
# 23  https://www.amazon.com/dp/B084CVPLLC/ref=emc_b...
# 24  https://www.amazon.com/dp/B084CVPLLC/ref=emc_b...
# 25  https://www.amazon.com/dp/B084D89DBF/ref=emc_b...
# 26  https://www.amazon.com/dp/B086H4C8CX/ref=emc_b...
# 27  https://www.amazon.com/dp/B086H3HH5V/ref=emc_b...
#
#                        product_description  \
# 0   This is the description of the product
# 1   This is the description of the product
# 2   This is the description of the product
# 3   This is the description of the product
# 4   This is the description of the product
# 5   This is the description of the product
# 6   This is the description of the product
# 7   This is the description of the product
# 8   This is the description of the product
# 9   This is the description of the product
# 10  This is the description of the product
# 11  This is the description of the product
# 12  This is the description of the product
# 13  This is the description of the product
# 14  This is the description of the product
# 15  This is the description of the product
# 16  This is the description of the product
# 17  This is the description of the product
# 18  This is the description of the product
# 19  This is the description of the product
# 20  This is the description of the product
# 21  This is the description of the product
# 22  This is the description of the product
# 23  This is the description of the product
# 24  This is the description of the product
# 25  This is the description of the product
# 26  This is the description of the product
# 27  This is the description of the product
#
#                                             image_url category  ram  storage  \
# 0   https://images-na.ssl-images-amazon.com/images...    phone    8      128
# 1   https://images-na.ssl-images-amazon.com/images...    phone    8      128
# 2   https://images-na.ssl-images-amazon.com/images...    phone    3       64
# 3   https://images-na.ssl-images-amazon.com/images...    phone    4       64
# 4   https://images-na.ssl-images-amazon.com/images...    phone    4       64
# 5   https://static.digit.in/product/thumb_160001_p...    phone    8      128
# 6   https://images-na.ssl-images-amazon.com/images...    phone    6       64
# 7   https://images-na.ssl-images-amazon.com/images...    phone    6      128
# 8                                                 NaN    phone    6      128
# 9                                                 NaN    phone    4      128
# 10                                                NaN    phone    6      128
# 11                                                NaN    phone    4      128
# 12                                                NaN    phone    4      128
# 13                                                NaN    phone    4      128
# 14                                                NaN    phone    8      128
# 15                                                NaN    phone    6      128
# 16                                                NaN    phone    4       64
# 17                                                NaN    phone    6      128
# 18                                                NaN    phone    4      128
# 19                                                NaN    phone    3       32
# 20                                                NaN    phone    4      128
# 21                                                NaN    phone    6      256
# 22                                                NaN    phone    4      128
# 23                                                NaN    phone    4      128
# 24                                                NaN    phone    4      128
# 25                                                NaN    phone    4       64
# 26                                                NaN    phone    3       32
# 27                                                NaN    phone    2       32
#
#     front_camera_megapixel  back_camera_megapixel  battery_mah  price_usd  \
# 0                     16.0                     36         3700        429
# 1                     10.0                     64         4500        875
# 2                      7.0                     12         2942        454
# 3                     12.0                     24         3110        635
# 4                     12.0                     36         3969        969
# 5                     16.0                     56         4510        829
# 6                      8.0                     28         3700        479
# 7                      NaN                     48         3800        669
# 8                     13.0                     64         5020        210
# 9                      8.0                     48         5000        198
# 10                    10.0                    108         4500       1099
# 11                    32.0                     64          400        580
# 12                    32.0                     48          400        269
# 13                    32.0                     48          400        399
# 14                    12.0                     32         4500        599
# 15                     8.0                     64         4300        299
# 16                     8.0                     48         5000        209
# 17                    16.0                     48         5000        379
# 18                    16.0                     48         4000        279
# 19                     5.0                     13         5000        159
# 20                    10.0                     64         4500        549
# 21                    25.0                     64         4500        499
# 22                     6.0                     48         3500        239
# 23                    16.0                     48         4000        229
# 24                     6.0                     48         4000        229
# 25                     6.0                     16         5000        219
# 26                     8.0                     16         4000        169
# 27                     5.0                     13         3550        199
#
#     user_rating  battery_backup  display_size
# 0           4.5             NaN           NaN
# 1           4.0             NaN           NaN
# 2           NaN             NaN           NaN
# 3           NaN             NaN           NaN
# 4           4.5             NaN           NaN
# 5           NaN             NaN           NaN
# 6           4.0             NaN           NaN
# 7           4.5             NaN           NaN
# 8           4.5             NaN           NaN
# 9           4.4             NaN           NaN
# 10          4.6             NaN           NaN
# 11          4.5             NaN           NaN
# 12          4.4             NaN           NaN
# 13          4.4             NaN           NaN
# 14          4.6             NaN           NaN
# 15          4.3             NaN           NaN
# 16          4.6             NaN           NaN
# 17          4.3             NaN           NaN
# 18          4.5             NaN           NaN
# 19          4.6             NaN           NaN
# 20          4.1             NaN           NaN
# 21          4.0             NaN           NaN
# 22          4.0             NaN           NaN
# 23          4.5             NaN           NaN
# 24          4.5             NaN           NaN
# 25          4.6             NaN           NaN
# 26          4.6             NaN           NaN
# 27          4.4             NaN           NaN

# %%
ram = 4
battery = 4000
budget = 450
camera = 48
myList = ['ram', 'back_camera_megapixel', 'battery_mah', 'price_usd']
df['ram'] = pd.to_numeric(df['ram'])
df['back_camera_megapixel'] = pd.to_numeric(df['back_camera_megapixel'])
df['price_usd'] = pd.to_numeric(df['price_usd'])
df['battery_mah'] = pd.to_numeric(df['battery_mah'])


record = df[(df['ram'] >= ram) & (df['back_camera_megapixel'] == camera) & (df['battery_mah'] >= battery) & (df['price_usd'] <= budget)]

# %%
for indices, row in record.iterrows():
    _ram = row['ram']
    _camera = row['back_camera_megapixel']
    _battery = row['battery_mah']
    _budget = row['price_usd']
    _product_name = row['product_name']
    
    print(_ram, _camera , _battery, _budget, _product_name)
# Out:
# 4 48 5000 198 Xiaomi Redmi Note 9
# 4 48 5000 209 Moto G Power
# 6 48 5000 379 Motorola One 5G Ace
# 4 48 4000 279 Moto G Stylus
# 4 48 4000 229 Moto G Stylus
# 4 48 4000 229 Moto G Stylus 2020

# %%
if len(record['ram']) != 0:
    print('hye')
else:
    print('Ho')
# Out:
# hye
