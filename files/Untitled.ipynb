# %%
import pandas as pd

# %%
df = pd.read_csv('./phones_02.csv', encoding='latin1')
df.head()
# Out:
#               product_name                                        product_url  \
# 0               OnePlus 6T  https://www.amazon.in/OnePlus-Mirror-Black-128...
# 1  Samsung Galaxy S20 Plus  https://www.amazon.com/Samsung-Unlocked-Finger...
# 2          Apple iPhone XR  https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 3          Apple iPhone 11  https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 4  Apple iPhone 11 Pro Max  https://www.amazon.com/Apple-iPhone-Midnight-U...
#
#                       product_description  \
# 0  This is the description of the product
# 1  This is the description of the product
# 2  This is the description of the product
# 3  This is the description of the product
# 4  This is the description of the product
#
#                                            image_url category  ram  storage  \
# 0  https://images-na.ssl-images-amazon.com/images...    phone    8      128
# 1  https://images-na.ssl-images-amazon.com/images...    phone    8      128
# 2  https://images-na.ssl-images-amazon.com/images...    phone    3       64
# 3  https://images-na.ssl-images-amazon.com/images...    phone    4       64
# 4  https://images-na.ssl-images-amazon.com/images...    phone    4       64
#
#    front_camera_megapixel  back_camera_megapixel  battery_mah  price_usd  \
# 0                    16.0                     36         3700        429
# 1                    10.0                     64         4500        875
# 2                     7.0                     12         2942        454
# 3                    12.0                     24         3110        635
# 4                    12.0                     36         3969        969
#
#    user_rating  battery_backup  display_size
# 0          4.5             NaN           NaN
# 1          4.0             NaN           NaN
# 2          NaN             NaN           NaN
# 3          NaN             NaN           NaN
# 4          4.5             NaN           NaN

# %%
df['ram'] = pd.to_numeric(df['ram'])
df['back_camera_megapixel'] = pd.to_numeric(df['back_camera_megapixel'])
df['price_usd'] = pd.to_numeric(df['price_usd'])
df['battery_mah'] = pd.to_numeric(df['battery_mah'])


record = df[(df['ram'] >= 6) & (df['back_camera_megapixel'] == 64) & (df['battery_mah'] >= 3000) & (df['price_usd'] <= 2000)]

# %%
record
# Out:
#                product_name  \
# 1   Samsung Galaxy S20 Plus
# 8   Xiaomi Redmi Note 9 Pro
# 15      OnePlus Nord N10 5G
# 21            Motorola Edge
#
#                                           product_url  \
# 1   https://www.amazon.com/Samsung-Unlocked-Finger...
# 8   https://www.amazon.com/Xiaomi-Redmi-Note-Pro-D...
# 15  https://www.amazon.com/OnePlus-Unlocked-Smartp...
# 21  https://www.amazon.com/Motorola-Unlocked-256GB...
#
#                        product_description  \
# 1   This is the description of the product
# 8   This is the description of the product
# 15  This is the description of the product
# 21  This is the description of the product
#
#                                             image_url category  ram  storage  \
# 1   https://images-na.ssl-images-amazon.com/images...    phone    8      128
# 8                                                 NaN    phone    6      128
# 15                                                NaN    phone    6      128
# 21                                                NaN    phone    6      256
#
#     front_camera_megapixel  back_camera_megapixel  battery_mah  price_usd  \
# 1                     10.0                     64         4500        875
# 8                     13.0                     64         5020        210
# 15                     8.0                     64         4300        299
# 21                    25.0                     64         4500        499
#
#     user_rating  battery_backup  display_size
# 1           4.0             NaN           NaN
# 8           4.5             NaN           NaN
# 15          4.3             NaN           NaN
# 21          4.0             NaN           NaN
