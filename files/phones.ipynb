# %%
import pandas as pd

# %%
df = pd.read_csv('phones_02.csv', encoding='latin1')

# %%
df.head()
# Out:
#               product_name                                        product_url  \
# 0               OnePlus 6T  https://www.amazon.in/OnePlus-Mirror-Black-128...
# 1  Samsung Galaxy S20 Plus                            https://amzn.to/3vs5TIS
# 2          Apple iPhone XR                            https://amzn.to/3pWO1Fe
# 3          Apple iPhone 11                            https://amzn.to/3gD50rw
# 4  Apple iPhone 11 Pro Max                            https://amzn.to/35l5zRA
#
#                       product_description  \
# 0  This is the description of the product
# 1  This is the description of the product
# 2  This is the description of the product
# 3  This is the description of the product
# 4  This is the description of the product
#
#                                            image_url category  ram  storage  \
# 0  https://images-na.ssl-images-amazon.com/images...    phone    8      128
# 1  https://images-na.ssl-images-amazon.com/images...    phone    8      128
# ...

# %%
df['price_usd'][4]
# Out:
# 969

# %%
for indices, row in df.iterrows():
    df['price_usd'][indices] = int(row['price_usd']) * 156.85
# Out:
# <ipython-input-38-450ee58e66ca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_usd'][indices] = int(row['price_usd']) * 156.85

# %%
df.to_csv('phones_2.csv')

# %%
df
# Out:
#                                    product_name  \
# 0                                    OnePlus 6T
# 1                       Samsung Galaxy S20 Plus
# 2                               Apple iPhone XR
# 3                               Apple iPhone 11
# 4                       Apple iPhone 11 Pro Max
# 5                                 OnePlus 8 Pro
# 6                             Google Pixel 4 XL
# 7                                 OnePLus 7 Pro
# 8                       Xiaomi Redmi Note 9 Pro
# 9                           Xiaomi Redmi Note 9
# 10  Samsung Electronics Galaxy Note 20 Ultra 5G
# 11                       Samsung Galaxy A71 5G
# 12                           Samsung Galaxy A51
# 13     Samsung Galaxy A51 Storage Compatibility
# 14                     Samsung Galaxy S20 FE 5G
# 15                          OnePlus Nord N10 5G
# 16                                 Moto G Power
# 17                          Motorola One 5G Ace
# ...
